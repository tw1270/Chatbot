# %% [markdown]
# # Chatbot

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# %% [markdown]
# ## Preprocessing

# %%
words=[]
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']
for intent in intents['intents']:
    for pattern in intent['patterns']:
        #tokenize each word

        word = nltk.word_tokenize(pattern)
        words.extend(word)        

        #add documents in the corpus
        documents.append((word, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])
print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ## Create Training and Testing Data

# %%
# create the training data
training = []
# create empty array for the output
output_empty = [0] * len(classes)
# training set, bag of words for every sentence
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    word_patterns = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]

    # create the bag of words array with 1, if word is found in current pattern
    for word in words:
        bag.append(1) if word in word_patterns else bag.append(0)     
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])
# shuffle the features and make numpy array
random.shuffle(training)
training = np.array(training)
# create training and testing lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data is created")
# Out:
# Training data is created
# <ipython-input-4-3c50ca68d0bf>:23: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)

# %% [markdown]
# ## Training the Model

# %%
# deep neural networds model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))
# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
#Training and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 998us/step - loss: 2.2097 - accuracy: 0.1426
# Epoch 2/200
# 10/10 [==============================] - 0s 888us/step - loss: 2.1847 - accuracy: 0.1499
# Epoch 3/200
# 10/10 [==============================] - 0s 889us/step - loss: 2.0105 - accuracy: 0.3030
# Epoch 4/200
# 10/10 [==============================] - 0s 795us/step - loss: 1.9086 - accuracy: 0.3436
# Epoch 5/200
# 10/10 [==============================] - 0s 888us/step - loss: 1.7924 - accuracy: 0.4342
# Epoch 6/200
# 10/10 [==============================] - 0s 777us/step - loss: 1.6050 - accuracy: 0.6314
# Epoch 7/200
# 10/10 [==============================] - 0s 778us/step - loss: 1.5192 - accuracy: 0.5595
# Epoch 8/200
# 10/10 [==============================] - 0s 777us/step - loss: 1.2751 - accuracy: 0.6551
# Epoch 9/200
# 10/10 [==============================] - 0s 776us/step - loss: 1.1242 - accuracy: 0.7071
# Epoch 10/200
# 10/10 [==============================] - 0s 778us/step - loss: 1.0820 - accuracy: 0.7759
# Epoch 11/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.9174 - accuracy: 0.8619
# Epoch 12/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.9118 - accuracy: 0.7831
# Epoch 13/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.6807 - accuracy: 0.9002
# Epoch 14/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.7519 - accuracy: 0.8412
# Epoch 15/200
# 10/10 [==============================] - 0s 887us/step - loss: 0.7996 - accuracy: 0.7398
# Epoch 16/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.5015 - accuracy: 0.9499
# Epoch 17/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.4881 - accuracy: 0.8531
# Epoch 18/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.5536 - accuracy: 0.7504
# Epoch 19/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.4299 - accuracy: 0.8605
# Epoch 20/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.5091 - accuracy: 0.8977
# Epoch 21/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.5498 - accuracy: 0.8127
# Epoch 22/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.2364 - accuracy: 0.9561
# Epoch 23/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.2538 - accuracy: 0.9365
# Epoch 24/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.2762 - accuracy: 0.9275
# Epoch 25/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.1805 - accuracy: 0.9902
# Epoch 26/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.2040 - accuracy: 0.9604
# Epoch 27/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.2424 - accuracy: 0.9780
# Epoch 28/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.2916 - accuracy: 0.9167
# Epoch 29/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.3006 - accuracy: 0.9280
# Epoch 30/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.2189 - accuracy: 0.9447
# Epoch 31/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.3134 - accuracy: 0.8159
# Epoch 32/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.2497 - accuracy: 0.9570
# Epoch 33/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0988 - accuracy: 1.0000
# Epoch 34/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0910 - accuracy: 0.9826
# Epoch 35/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1151 - accuracy: 0.9880
# Epoch 36/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.1031 - accuracy: 0.9673
# Epoch 37/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0687 - accuracy: 1.0000
# Epoch 38/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1615 - accuracy: 0.9718
# Epoch 39/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 40/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1030 - accuracy: 1.0000
# Epoch 41/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.1337 - accuracy: 0.9859
# Epoch 42/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.2340 - accuracy: 0.9077
# Epoch 43/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1385 - accuracy: 0.9941
# Epoch 44/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.6469 - accuracy: 0.9100
# Epoch 45/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.2005 - accuracy: 0.9280
# Epoch 46/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1078 - accuracy: 0.9629
# Epoch 47/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.2092 - accuracy: 0.9076
# Epoch 48/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1335 - accuracy: 0.9780
# Epoch 49/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0985 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1944 - accuracy: 0.9570
# Epoch 51/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0924 - accuracy: 0.9941
# Epoch 52/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.2047 - accuracy: 0.9068
# Epoch 53/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0943 - accuracy: 0.9755
# Epoch 54/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0841 - accuracy: 0.9859
# Epoch 55/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0769 - accuracy: 0.9918
# Epoch 56/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0848 - accuracy: 0.9720
# Epoch 57/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0787 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.0548 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0636 - accuracy: 0.9918
# Epoch 60/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 667us/step - loss: 0.1056 - accuracy: 0.9811
# Epoch 62/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0777 - accuracy: 0.9447
# Epoch 63/200
# 10/10 [==============================] - 0s 1000us/step - loss: 0.2156 - accuracy: 0.9388
# Epoch 64/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0873 - accuracy: 0.9721
# Epoch 65/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0861 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.1080 - accuracy: 0.9606
# Epoch 67/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0778 - accuracy: 0.9606
# Epoch 68/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0616 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0630 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 890us/step - loss: 0.1083 - accuracy: 0.9409
# Epoch 74/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0620 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0744 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0631 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 664us/step - loss: 0.0660 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0933 - accuracy: 0.9862
# Epoch 80/200
# 10/10 [==============================] - 0s 779us/step - loss: 0.0928 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 779us/step - loss: 0.0484 - accuracy: 0.9862
# Epoch 82/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0429 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0615 - accuracy: 1.0000
# Epoch 85/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 667us/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 91/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0556 - accuracy: 0.9826
# Epoch 92/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0584 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0763 - accuracy: 0.9780
# Epoch 94/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0759 - accuracy: 0.9606
# Epoch 95/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0890 - accuracy: 0.9918
# Epoch 97/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0522 - accuracy: 0.9918
# Epoch 98/200
# 10/10 [==============================] - 0s 667us/step - loss: 0.0575 - accuracy: 0.9918
# Epoch 99/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0295 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0517 - accuracy: 0.9629
# Epoch 103/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0389 - accuracy: 0.9826
# Epoch 105/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0556 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0196 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0351 - accuracy: 0.9862
# Epoch 115/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0316 - accuracy: 0.9826
# Epoch 117/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0387 - accuracy: 0.9862
# Epoch 118/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0331 - accuracy: 0.9767
# Epoch 120/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0282 - accuracy: 0.9892
# Epoch 121/200
# 10/10 [==============================] - 0s 999us/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0503 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0347 - accuracy: 0.9918
# Epoch 127/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0459 - accuracy: 0.9826
# Epoch 129/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0345 - accuracy: 0.9780
# Epoch 130/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 889us/step - loss: 0.0364 - accuracy: 0.9826
# Epoch 133/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0910 - accuracy: 0.9834
# Epoch 134/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0749 - accuracy: 0.9447
# Epoch 142/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0614 - accuracy: 0.9826
# Epoch 145/200
# 10/10 [==============================] - 0s 779us/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0298 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0156 - accuracy: 0.9941
# Epoch 158/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0377 - accuracy: 0.9918
# Epoch 161/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0208 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0374 - accuracy: 0.9826
# Epoch 168/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.1126 - accuracy: 0.9447
# Epoch 169/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0509 - accuracy: 0.9629
# Epoch 171/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0180 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0478 - accuracy: 0.9629
# Epoch 173/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 174/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0136 - accuracy: 0.9941
# Epoch 175/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0228 - accuracy: 0.9941
# Epoch 181/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0361 - accuracy: 0.9780
# Epoch 190/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0355 - accuracy: 0.9720
# Epoch 191/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0224 - accuracy: 0.9862
# Epoch 194/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 666us/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 779us/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 777us/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0316 - accuracy: 0.9780
# model is created
